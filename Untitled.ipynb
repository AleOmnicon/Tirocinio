# %%
import pandas as pd
import numpy as np
import os
import sys
from skforecast.ForecasterAutoreg import ForecasterAutoreg  ## fare riferimento alla documentazione di skforecast
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
import time
from sklearn.metrics import r2_score, mean_absolute_percentage_error
import matplotlib.pyplot as plt
from skforecast.model_selection import grid_search_forecaster

# %% [markdown]
# ### COSTANTI

# %%
DATE_LIMITER = "2023-08-01 00:00:00"
TRAIN_SET_PERC = 0.8
LAGS = [96, 192, 288, 384, 480] # 1,2,3,4,5 giorni
STEPS = 4 # 1h

# %% [markdown]
# ### FUNZIONI

# %%
def predict(setToPredict ,lags, steps):
    i=0
    lenVal = len(setToPredict)
    newPreds = []
    newTimes = []
    while(i + lags < lenVal):
        print(f"step {i+1}/{lenVal - lags}", end="\r")
        batch = setToPredict.iloc[i:i + lags]["Value"]
        betterPred = model.predict(steps , last_window=batch)
        newPreds.append(betterPred.iloc[-1])
        newTimes.append(betterPred.index[-1])
        i += 1
    pred = pd.Series(newPreds, newTimes)
    print("\n")
    return pred

# %%
def printScore(realData, predictedData):
    mape = mean_absolute_percentage_error(realData, predictedData)
    r2 = r2_score(realData, predictedData)
    print("___SCORE___")
    print(f"mape: {mape}")
    print(f"r2: {r2}")

# %% [markdown]
# ### DATI

# %%
PATH = os.path.dirname(os.path.abspath("__file__"))
PATH = os.path.join(PATH, "data", "trendLvSolignanoUlia.csv")

allData = pd.read_csv(PATH,delimiter=";")
allData.columns = ["Time", "Value"]
allData["Time"] = pd.to_datetime(allData["Time"])
allData.set_index("Time", inplace=True)
allData = allData.resample(rule="15T").mean().ffill()

# %%
stableData = allData[allData.index < DATE_LIMITER]

setDivisor = int(len(stableData) * TRAIN_SET_PERC)

trainingSet = stableData.iloc[:setDivisor]
validationSet = stableData.iloc[setDivisor:]

# %%
strangeData = allData[allData.index >= DATE_LIMITER]

# %% [markdown]
# #### DIVISIONE DI 30 MINUTI

# %%
allDataHalfH = allData.resample(rule="30T").mean().ffill()

# %%
plt.plot(allDataHalfH)
plt.plot(allData)

# %% [markdown]
# ### TRAINING

# %%
xgb = XGBRegressor()
lags = LAGS[0]

model = ForecasterAutoreg(regressor=xgb, lags=lags)

start=time.time()
model.fit(trainingSet["Value"])
end= time.time()
print(f"\nTRAINING TIME: {(end - start):.3} s")
# Out:
# TRAINING TIME: 2.41 s

# %%
makePrediction(trainingSet, LAGS[0], STEPS, "Training")
# Out:
# step 15251/15251
#
# predizione sul Training set: 48 s
# ___SCORE___
# mape: 0.001968701606953373
# r2: 0.9930117564092135
# mse: 0.47364389153925246

# %%
makePrediction(validationSet, LAGS[0], STEPS, "Validation")
# Out:
# step 3741/3741
#
# predizione sul Validation set: 12 s
# ___SCORE___
# mape: 0.0052383058596903774
# r2: 0.9444069765579979
# mse: 4.016150984084237

# %%
start = time.time()
predVal = predict(strangeData, LAGS[0], STEPS)
plt.plot(predVal, label="predizione Strange set")
end = time.time()
print(f"predizione sulo Strange set: {int(end-start)} s")
# Out:
# step 10721/10721
#
# predizione sulo Strange set: 39 s

# %%
predVal.iloc[:-STEPS+1]
# Out:
# 2023-08-02 00:45:00    253.196274
# 2023-08-02 01:00:00    253.320023
# 2023-08-02 01:15:00    253.146301
# 2023-08-02 01:30:00    252.857895
# 2023-08-02 01:45:00    253.445358
#                           ...
# 2023-11-21 15:45:00    264.409760
# 2023-11-21 16:00:00    263.660187
# 2023-11-21 16:15:00    265.276001
# 2023-11-21 16:30:00    264.823761
# 2023-11-21 16:45:00    263.500671
# Length: 10721, dtype: float64

# %%
strangeData.iloc[STEPS-1:]
# Out:
#                       Value
# Time
# 2023-08-01 00:45:00  252.19
# 2023-08-01 01:00:00  252.56
# 2023-08-01 01:15:00  253.31
# 2023-08-01 01:30:00  252.91
# 2023-08-01 01:45:00  253.44
# ...                     ...
# 2023-11-21 15:00:00  269.50
# 2023-11-21 15:15:00  270.63
# 2023-11-21 15:30:00  268.09
# 2023-11-21 15:45:00  268.72
# 2023-11-21 16:00:00  268.34
#
# [10814 rows x 1 columns]

# %%
# Out:
# 0

# %%
printScore(allData.loc[predVal.iloc[:-STEPS+1].index].values, predVal.iloc[:-STEPS+1].values)
# Out:
# ___SCORE___
# mape: 0.35443973231472026
# r2: 0.11818326493676412

# %%
len(strangeData) - STEPS
# Out:
# 10813

# %%
len(strangeData)
# Out:
# 10817

# %%
predVa

# %%
plt.legend()
plt.show()
# Out:
# matplotlib.legend WARNING No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
mape = 0.001234567
r2 = 0.11223344

txt = f"SCORE\nmape: {mape:.5}\nr2: {r2:.5}"
fig, ax = plt.subplots(figsize=(5, 5))
t = ax.text(0.5, 0.1, txt)

# %%
plt.annotate(txt, "figure fraction")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 plt.annotate(txt, "figure fraction")
#
# File c:\users\astefani\appdata\local\programs\python\python39\lib\site-packages\matplotlib\pyplot.py:2650, in annotate(text, xy, xytext, xycoords, textcoords, arrowprops, annotation_clip, **kwargs)
#    2630 @_copy_docstring_and_deprecators(Axes.annotate)
#    2631 def annotate(
#    2632     text: str,
#    (...)
#    2648     **kwargs,
#    2649 ) -> Annotation:
# -> 2650     return gca().annotate(
#    2651         text,
#    2652         xy,
#    2653         xytext=xytext,
#    2654         xycoords=xycoords,
#    2655         textcoords=textcoords,
#    2656         arrowprops=arrowprops,
#    2657         annotation_clip=annotation_clip,
#    2658         **kwargs,
#    2659     )
#
# File c:\users\astefani\appdata\local\programs\python\python39\lib\site-packages\matplotlib\axes\_axes.py:711, in Axes.annotate(self, text, xy, xytext, xycoords, textcoords, arrowprops, annotation_clip, **kwargs)
#     706 @_docstring.dedent_interpd
#     707 def annotate(self, text, xy, xytext=None, xycoords='data', textcoords=None,
#     708              arrowprops=None, annotation_clip=None, **kwargs):
#     709     # Signature must match Annotation. This is verified in
#     710     # test_annotate_signature().
# --> 711     a = mtext.Annotation(text, xy, xytext=xytext, xycoords=xycoords,
#     712                          textcoords=textcoords, arrowprops=arrowprops,
#     713                          annotation_clip=annotation_clip, **kwargs)
#     714     a.set_transform(mtransforms.IdentityTransform())
#     715     if kwargs.get('clip_on', False) and a.get_clip_path() is None:
#
# File c:\users\astefani\appdata\local\programs\python\python39\lib\site-packages\matplotlib\text.py:1805, in Annotation.__init__(self, text, xy, xytext, xycoords, textcoords, arrowprops, annotation_clip, **kwargs)
#    1633 def __init__(self, text, xy,
#    1634              xytext=None,
#    1635              xycoords='data',
#    (...)
#    1638              annotation_clip=None,
#    1639              **kwargs):
#    1640     """
#    1641     Annotate the point *xy* with text *text*.
#    1642
#    (...)
#    1803
#    1804     """
# -> 1805     _AnnotationBase.__init__(self,
#    1806                              xy,
#    1807                              xycoords=xycoords,
#    1808                              annotation_clip=annotation_clip)
#    1809     # warn about wonky input data
#    1810     if (xytext is None and
#    1811             textcoords is not None and
#    1812             textcoords != xycoords):
#
# File c:\users\astefani\appdata\local\programs\python\python39\lib\site-packages\matplotlib\text.py:1450, in _AnnotationBase.__init__(self, xy, xycoords, annotation_clip)
#    1445 def __init__(self,
#    1446              xy,
#    1447              xycoords='data',
#    1448              annotation_clip=None):
# -> 1450     x, y = xy  # Make copy when xy is an array (and check the shape).
#    1451     self.xy = x, y
#    1452     self.xycoords = xycoords
#
# ValueError: too many values to unpack (expected 2)

# %%
a = [5,4,3,2,1]
b= [11, 12]

# %%
a += [0]
a
# Out:
# [5, 4, 3, 2, 1, 0]

# %%
a+b
# Out:
# [5, 4, 3, 2, 1, 0, 11, 12]

# %%
xgb = XGBRegressor()

# %%
model = ForecasterAutoreg(xgb, 10)
lagGrid = [LAGS]

# %%
forecaster = ForecasterAutoreg(
                regressor = xgb,
                lags      = 12 # Placeholder, the value will be overwritten
             )

# Regressor hiperparameters
param_grid = {}

# Lags used as predictors
lags_grid = [5, 12, [1, 2, 3, 20]]

results_grid = grid_search_forecaster(
                        forecaster  = forecaster,
                        y           = trainingSet["Value"] + validationSet["Value"],
                        param_grid  = param_grid,
                        lags_grid   = lags_grid,
                        steps       = 96,
                        metric      = 'mean_absolute_percentage_error',
                        initial_train_size    = int(len(trainingSet)),
                        allow_incomplete_fold = False,
                        return_best = True,
                        verbose     = False
                    )
# Out:
# Number of models compared: 3.
# lags grid:   0%|          | 0/3 [00:00<?, ?it/s]
# params grid:   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 12
#       9 # Lags used as predictors
#      10 lags_grid = [5, 12, [1, 2, 3, 20]]
# ---> 12 results_grid = grid_search_forecaster(
#      13                         forecaster  = forecaster,
#      14                         y           = trainingSet["Value"] + validationSet["Value"],
#      15                         param_grid  = param_grid,
#      16                         lags_grid   = lags_grid,
#      17                         steps       = 96,
#      18                         metric      = 'mean_absolute_percentage_error',
#      19                         initial_train_size    = int(len(trainingSet)),
#      20                         allow_incomplete_fold = False,
#      21                         return_best = True,
#      22                         verbose     = False
#      23                     )
#
# File c:\users\astefani\appdata\local\programs\python\python39\lib\site-packages\skforecast\model_selection\model_selection.py:910, in grid_search_forecaster(forecaster, y, param_grid, steps, metric, initial_train_size, fixed_train_size, gap, allow_incomplete_fold, exog, lags_grid, refit, return_best, n_jobs, verbose, show_progress)
#     841 """
#     842 Exhaustive search over specified parameter values for a Forecaster object.
#     843 Validation is done using time series backtesting.
#    (...)
#     905
#     906 """
#     908 param_grid = list(ParameterGrid(param_grid))
# --> 910 results = _evaluate_grid_hyperparameters(
#     911     forecaster            = forecaster,
#     912     y                     = y,
#     913     param_grid            = param_grid,
#     914     steps                 = steps,
#     915     metric                = metric,
#     916     initial_train_size    = initial_train_size,
#     917     fixed_train_size      = fixed_train_size,
#     918     gap                   = gap,
#     919     allow_incomplete_fold = allow_incomplete_fold,
#     920     exog                  = exog,
#     921     lags_grid             = lags_grid,
#     922     refit                 = refit,
#     923     return_best           = return_best,
#     924     n_jobs                = n_jobs,
#     925     verbose               = verbose,
#     926     show_progress         = show_progress
#     927 )
#     929 return results
#
# File c:\users\astefani\appdata\local\programs\python\python39\lib\site-packages\skforecast\model_selection\model_selection.py:1175, in _evaluate_grid_hyperparameters(forecaster, y, param_grid, steps, metric, initial_train_size, fixed_train_size, gap, allow_incomplete_fold, exog, lags_grid, refit, return_best, n_jobs, verbose, show_progress)
#    1172 for params in param_grid:
#    1174     forecaster.set_params(params)
# -> 1175     metrics_values = backtesting_forecaster(
#    1176                          forecaster            = forecaster,
#    1177                          y                     = y,
#    1178                          steps                 = steps,
#    1179                          metric                = metric,
#    1180                          initial_train_size    = initial_train_size,
#    1181                          fixed_train_size      = fixed_train_size,
#    1182                          gap                   = gap,
#    1183                          allow_incomplete_fold = allow_incomplete_fold,
#    1184                          exog                  = exog,
#    1185                          refit                 = refit,
#    1186                          interval              = None,
#    1187                          n_jobs                = n_jobs,
#    1188                          verbose               = verbose,
#    1189                          show_progress         = False
#    1190                      )[0]
#    1191     warnings.filterwarnings('ignore', category=RuntimeWarning, message= "The forecaster will be fit.*")
#    1192     lags_list.append(lags)
#
# File c:\users\astefani\appdata\local\programs\python\python39\lib\site-packages\skforecast\model_selection\model_selection.py:800, in backtesting_forecaster(forecaster, y, steps, metric, initial_train_size, fixed_train_size, gap, allow_incomplete_fold, exog, refit, interval, n_boot, random_state, in_sample_residuals, n_jobs, verbose, show_progress)
#     792 if type(forecaster).__name__ == 'ForecasterAutoregDirect' and \
#     793    forecaster.steps < steps + gap:
#     794     raise ValueError(
#     795         ("When using a ForecasterAutoregDirect, the combination of steps "
#     796          f"+ gap ({steps+gap}) cannot be greater than the `steps` parameter "
#     797          f"declared when the forecaster is initialized ({forecaster.steps}).")
#     798     )
# --> 800 metrics_values, backtest_predictions = _backtesting_forecaster(
#     801     forecaster            = forecaster,
#     802     y                     = y,
#     803     steps                 = steps,
#     804     metric                = metric,
#     805     initial_train_size    = initial_train_size,
#     806     fixed_train_size      = fixed_train_size,
#     807     gap                   = gap,
#     808     allow_incomplete_fold = allow_incomplete_fold,
#     809     exog                  = exog,
#     810     refit                 = refit,
#     811     interval              = interval,
#     812     n_boot                = n_boot,
#     813     random_state          = random_state,
#     814     in_sample_residuals   = in_sample_residuals,
#     815     n_jobs                = n_jobs,
#     816     verbose               = verbose,
#     817     show_progress         = show_progress
#     818 )
#     820 return metrics_values, backtest_predictions
#
# File c:\users\astefani\appdata\local\programs\python\python39\lib\site-packages\skforecast\model_selection\model_selection.py:512, in _backtesting_forecaster(forecaster, y, steps, metric, initial_train_size, fixed_train_size, gap, allow_incomplete_fold, exog, refit, interval, n_boot, random_state, in_sample_residuals, n_jobs, verbose, show_progress)
#     508 if initial_train_size is not None:
#     509     # First model training, this is done to allow parallelization when `refit`
#     510     # is `False`. The initial Forecaster fit is outside the auxiliary function.
#     511     exog_train = exog.iloc[:initial_train_size, ] if exog is not None else None
# --> 512     forecaster.fit(
#     513         y                         = y.iloc[:initial_train_size, ],
#     514         exog                      = exog_train,
#     515         store_in_sample_residuals = store_in_sample_residuals
#     516     )
#     517     window_size = forecaster.window_size
#     518     externally_fitted = False
#
# File c:\users\astefani\appdata\local\programs\python\python39\lib\site-packages\skforecast\ForecasterAutoreg\ForecasterAutoreg.py:525, in ForecasterAutoreg.fit(self, y, exog, store_in_sample_residuals)
#     521     self.exog_type = type(exog)
#     522     self.exog_col_names = \
#     523          exog.columns.to_list() if isinstance(exog, pd.DataFrame) else exog.name
# --> 525 X_train, y_train = self.create_train_X_y(y=y, exog=exog)
#     526 sample_weight = self.create_sample_weights(X_train=X_train)
#     528 if sample_weight is not None:
#
# File c:\users\astefani\appdata\local\programs\python\python39\lib\site-packages\skforecast\ForecasterAutoreg\ForecasterAutoreg.py:360, in ForecasterAutoreg.create_train_X_y(self, y, exog)
#     332 def create_train_X_y(
#     333     self,
#     334     y: pd.Series,
#     335     exog: Optional[Union[pd.Series, pd.DataFrame]]=None
#     336 ) -> Tuple[pd.DataFrame, pd.Series]:
#     337     """
#     338     Create training matrices from univariate time series and exogenous
#     339     variables.
#    (...)
#     357
#     358     """
# --> 360     check_y(y=y)
#     361     y = transform_series(
#     362             series            = y,
#     363             transformer       = self.transformer_y,
#     364             fit               = True,
#     365             inverse_transform = False
#     366         )
#     367     y_values, y_index = preprocess_y(y=y)
#
# File c:\users\astefani\appdata\local\programs\python\python39\lib\site-packages\skforecast\utils\utils.py:257, in check_y(y)
#     254     raise TypeError("`y` must be a pandas Series.")
#     256 if y.isnull().any():
# --> 257     raise ValueError("`y` has missing values.")
#     259 return
#
# ValueError: `y` has missing values.
